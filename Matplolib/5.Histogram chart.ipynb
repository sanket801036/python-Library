# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x=np.random.randint(10,60,(50))
print(x)
# Out:
# [15 43 46 33 21 13 16 55 58 49 37 42 54 39 11 12 30 44 44 11 13 27 47 36
#  39 31 19 18 48 14 59 11 49 35 37 18 39 24 52 36 38 38 32 37 13 37 10 46
#  33 46]

# %%
np=[15,43,46,33,21,13,16,55,58,49,37,42,54,39,11,12,30,44,44,11,13,27,47,36,39,31,19,18,48,14,59,11,49,35,37,18,39,24,52,36,38,38,32,37,13,37,10,46
,33,46]
l=[10,20,30,40,50,60]
# plt.hist(np,color="b",bins=l,edgecolor="r")
# plt.hist(np,"auto",(0,100),edgecolor="r")
# plt.hist(np,color="b",edgecolor="r",cumulative=-1)
plt.hist(np,color="b",edgecolor="r",bottom=10,align="left")
plt.title("JBK")
plt.ylabel("No.")
plt.xlabel("Python")

plt.axvline(45,color="r",label="line")
plt.grid()
plt.show()
